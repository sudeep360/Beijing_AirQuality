# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
air_quality=pd.read_csv('air_quality.csv')

# %%
air_quality
# Out:
#                  date_time  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0      2013-03-01 00:00:00    9.0   9.0   3.0  17.0  300.0  89.0  -0.5
# 1      2013-03-01 01:00:00    4.0   4.0   3.0  16.0  300.0  88.0  -0.7
# 2      2013-03-01 05:00:00    4.0   4.0   9.0  25.0  300.0  78.0  -2.4
# 3      2013-03-01 06:00:00    5.0   5.0  10.0  29.0  400.0  67.0  -2.5
# 4      2013-03-01 07:00:00    3.0   6.0  12.0  40.0  400.0  52.0  -1.4
# ...                    ...    ...   ...   ...   ...    ...   ...   ...
# 95680  2017-02-28 15:00:00    9.0   9.0   2.0  22.0  300.0  91.0  15.4
# 95681  2017-02-28 16:00:00   10.0  29.0   3.0  21.0  300.0  94.0  14.9
# 95682  2017-02-28 21:00:00   18.0  32.0   4.0  48.0  500.0  48.0  10.8
# 95683  2017-02-28 22:00:00   15.0  42.0   5.0  52.0  600.0  44.0  10.5
# 95684  2017-02-28 23:00:00   15.0  50.0   5.0  68.0  700.0  21.0   8.6
#
#          PRES  DEWP  RAIN   wd  WSPM  station
# 0      1024.5 -21.4   0.0  NNW   5.7   Dongsi
# ...

# %%
air_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95685 entries, 0 to 95684
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date_time  95685 non-null  object
#  1   PM2.5      95685 non-null  float64
#  2   PM10       95685 non-null  float64
#  3   SO2        95685 non-null  float64
#  4   NO2        95685 non-null  float64
#  5   CO         95685 non-null  float64
#  6   O3         95685 non-null  float64
#  7   TEMP       95685 non-null  float64
#  8   PRES       95685 non-null  float64
#  9   DEWP       95685 non-null  float64
#  10  RAIN       95685 non-null  float64
#  11  wd         95685 non-null  object
#  12  WSPM       95685 non-null  float64
#  13  station    95685 non-null  object
# dtypes: float64(11), object(3)
# memory usage: 10.2+ MB

# %%
air_quality['date_time']=pd.to_datetime(air_quality['date_time'])

# %%
air_quality['date_time'].dt.year
# Out:
# 0        2013
# 1        2013
# 2        2013
# 3        2013
# 4        2013
#          ...
# 95680    2017
# 95681    2017
# 95682    2017
# 95683    2017
# 95684    2017
# Name: date_time, Length: 95685, dtype: int64

# %%
air_quality['year']=air_quality['date_time'].dt.year
air_quality
# Out:
#                 date_time  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  \
# 0     2013-03-01 00:00:00    9.0   9.0   3.0  17.0  300.0  89.0  -0.5  1024.5
# 1     2013-03-01 01:00:00    4.0   4.0   3.0  16.0  300.0  88.0  -0.7  1025.1
# 2     2013-03-01 05:00:00    4.0   4.0   9.0  25.0  300.0  78.0  -2.4  1027.5
# 3     2013-03-01 06:00:00    5.0   5.0  10.0  29.0  400.0  67.0  -2.5  1028.2
# 4     2013-03-01 07:00:00    3.0   6.0  12.0  40.0  400.0  52.0  -1.4  1029.5
# ...                   ...    ...   ...   ...   ...    ...   ...   ...     ...
# 95680 2017-02-28 15:00:00    9.0   9.0   2.0  22.0  300.0  91.0  15.4  1013.0
# 95681 2017-02-28 16:00:00   10.0  29.0   3.0  21.0  300.0  94.0  14.9  1012.6
# 95682 2017-02-28 21:00:00   18.0  32.0   4.0  48.0  500.0  48.0  10.8  1014.2
# 95683 2017-02-28 22:00:00   15.0  42.0   5.0  52.0  600.0  44.0  10.5  1014.4
# 95684 2017-02-28 23:00:00   15.0  50.0   5.0  68.0  700.0  21.0   8.6  1014.1
#
# ...

# %%
air_quality['month']=air_quality['date_time'].dt.month_name()
air_quality['day']=air_quality['date_time'].dt.day
air_quality['day_of_the_week']=air_quality['date_time'].dt.day_name()
air_quality['year']=air_quality['date_time'].dt.year

air_quality
# Out:
#                 date_time  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  \
# 0     2013-03-01 00:00:00    9.0   9.0   3.0  17.0  300.0  89.0  -0.5  1024.5
# 1     2013-03-01 01:00:00    4.0   4.0   3.0  16.0  300.0  88.0  -0.7  1025.1
# 2     2013-03-01 05:00:00    4.0   4.0   9.0  25.0  300.0  78.0  -2.4  1027.5
# 3     2013-03-01 06:00:00    5.0   5.0  10.0  29.0  400.0  67.0  -2.5  1028.2
# 4     2013-03-01 07:00:00    3.0   6.0  12.0  40.0  400.0  52.0  -1.4  1029.5
# ...                   ...    ...   ...   ...   ...    ...   ...   ...     ...
# 95680 2017-02-28 15:00:00    9.0   9.0   2.0  22.0  300.0  91.0  15.4  1013.0
# 95681 2017-02-28 16:00:00   10.0  29.0   3.0  21.0  300.0  94.0  14.9  1012.6
# 95682 2017-02-28 21:00:00   18.0  32.0   4.0  48.0  500.0  48.0  10.8  1014.2
# 95683 2017-02-28 22:00:00   15.0  42.0   5.0  52.0  600.0  44.0  10.5  1014.4
# 95684 2017-02-28 23:00:00   15.0  50.0   5.0  68.0  700.0  21.0   8.6  1014.1
#
# ...

# %%
datetime_range=air_quality['date_time'].max()-air_quality['date_time'].min()
datetime_range
# Out:
# Timedelta('1460 days 23:00:00')

# %%
datetime_range/pd.Timedelta(days=365)
# Out:
# 4.002625570776256

# %%
plt.hist(air_quality['year'],weights=air_quality['PM2.5'], bins=10)
plt.xlabel('Year')
plt.ylabel('PM2.5 Values')
# Out:
# Text(0, 0.5, 'PM2.5 Values')

# %%
air_quality['PM2.5'].hist()
# Out:
# <AxesSubplot:>

# %%
pm2_5=pd.cut(air_quality['PM2.5'],bins=10)
pm2_5
# Out:
# 0        (1.181, 83.9]
# 1        (1.181, 83.9]
# 2        (1.181, 83.9]
# 3        (1.181, 83.9]
# 4        (1.181, 83.9]
#              ...
# 95680    (1.181, 83.9]
# 95681    (1.181, 83.9]
# 95682    (1.181, 83.9]
# 95683    (1.181, 83.9]
# 95684    (1.181, 83.9]
# Name: PM2.5, Length: 95685, dtype: category
# Categories (10, interval[float64, right]): [(1.181, 83.9] < (83.9, 165.8] < (165.8, 247.7] < (247.7, 329.6] ... (493.4, 575.3] < (575.3, 657.2] < (657.2, 739.1] < (739.1, 821.0]]

# %%
pm2_5.value_counts()
# Out:
# (1.181, 83.9]     59923
# (83.9, 165.8]     22741
# (165.8, 247.7]     8132
# (247.7, 329.6]     3225
# (329.6, 411.5]     1011
# (411.5, 493.4]      384
# (493.4, 575.3]      171
# (575.3, 657.2]       70
# (657.2, 739.1]       22
# (739.1, 821.0]        6
# Name: PM2.5, dtype: int64

# %%
air_quality['PM2.5_category']=pd.cut(air_quality['PM2.5'], bins=[0,12,35.4,55.4,150.4,250.4,999],
                         labels=['Good','Moderate','Unhealthy for sensitive groups','Unhealthy','Very Unhealthy','Hazardous'])
air_quality['PM2.5_category'].value_counts()
# Out:
# Unhealthy                         34257
# Moderate                          19853
# Good                              13576
# Unhealthy for sensitive groups    12457
# Very Unhealthy                    10821
# Hazardous                          4721
# Name: PM2.5_category, dtype: int64

# %%
air_quality['PM2.5_category'].hist(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Mapping to new values

# %%
air_quality['day_of_the_week'].value_counts()
# Out:
# Sunday       13931
# Saturday     13812
# Friday       13782
# Thursday     13633
# Monday       13536
# Tuesday      13523
# Wednesday    13468
# Name: day_of_the_week, dtype: int64

# %%
day_of_the_week_mapping={
    'Monday':'Weekday',
    'Tuesday':'Weekday',
    'Wednesday':'Weekday',
    'Thursday':'Weekday',
    'Friday':'Weekday',
    'Saturday':'Weekend',
    'Sunday':'Weekend',
}
air_quality['day_of_the_week_type']=air_quality['day_of_the_week'].map(arg=day_of_the_week_mapping)

# %%
air_quality[['day_of_the_week','day_of_the_week_type']]
# Out:
#       day_of_the_week day_of_the_week_type
# 0              Friday              Weekday
# 1              Friday              Weekday
# 2              Friday              Weekday
# 3              Friday              Weekday
# 4              Friday              Weekday
# ...               ...                  ...
# 95680         Tuesday              Weekday
# 95681         Tuesday              Weekday
# 95682         Tuesday              Weekday
# 95683         Tuesday              Weekday
# 95684         Tuesday              Weekday
#
# [95685 rows x 2 columns]

# %%
air_quality.groupby(by=['day_of_the_week_type']).get_group('Weekend').reset_index()
# Out:
#        index           date_time  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0         21 2013-03-02 00:00:00    4.0  11.0  11.0  45.0  500.0  52.0  -0.7
# 1         22 2013-03-02 01:00:00    3.0   6.0  11.0  43.0  500.0  53.0  -1.6
# 2         23 2013-03-02 02:00:00    3.0   6.0  10.0  36.0  400.0  61.0  -2.2
# 3         24 2013-03-02 03:00:00    3.0   6.0  11.0  41.0  500.0  46.0  -3.1
# 4         25 2013-03-02 04:00:00    3.0   6.0   9.0  31.0  400.0  60.0  -3.1
# ...      ...                 ...    ...   ...   ...   ...    ...   ...   ...
# 27738  95640 2017-02-26 19:00:00   29.0  52.0   8.0  41.0  500.0  67.0  10.9
# 27739  95641 2017-02-26 20:00:00   36.0  58.0   9.0  56.0  700.0  47.0  10.3
# 27740  95642 2017-02-26 21:00:00   36.0  60.0   9.0  65.0  700.0  36.0   9.8
# 27741  95643 2017-02-26 22:00:00   43.0  80.0  10.0  76.0  900.0  20.0   8.5
# 27742  95644 2017-02-26 23:00:00   63.0  94.0  13.0  79.0  100.0  13.0   7.6
#
# ...

# %%
air_quality['TEMP_category']=pd.cut(air_quality['TEMP'], bins=[-20,0,10,20,30,40,50],
                                    labels=['Very Cold','Cold','Moderate','Warm','Hot','Extreamely Hot'])

# %%
air_quality.groupby(by='TEMP_category').mean()
# Out:
#                      PM2.5        PM10        SO2        NO2           CO  \
# TEMP_category
# Very Cold       104.434318  126.231759  24.705470  64.169078  2100.793459
# Cold             91.891125  118.463841  22.140692  62.036682  1583.868124
# Moderate         79.564596  114.915183  12.429350  57.751640  1090.871136
# Warm             73.480085  102.165824   9.070220  45.352282   979.090970
# Hot              62.050527   85.627254   7.323750  26.750017   781.726267
# Extreamely Hot   18.750000   50.250000   4.250000  23.500000   375.000000
#
#                         O3       TEMP         PRES       DEWP      RAIN  \
# TEMP_category
# Very Cold        21.554872  -3.224560  1023.784145 -13.690077  0.006216
# Cold             30.549967   4.742241  1018.221590  -7.757156  0.018118
# Moderate         43.013019  15.343161  1010.720102   4.540313  0.092842
# Warm             84.783743  24.663595  1002.611351  14.579215  0.122709
# ...

# %%
air_quality[['TEMP_category','PM2.5_category','day_of_the_week_type']].groupby('day_of_the_week_type').describe()
# Out:
#                      TEMP_category                     PM2.5_category         \
#                              count unique   top   freq          count unique
# day_of_the_week_type
# Weekday                      67942      6  Warm  20492          67942      6
# Weekend                      27743      5  Warm   8034          27743      6
#
#
#                             top   freq
# day_of_the_week_type
# Weekday               Unhealthy  24673
# Weekend               Unhealthy   9584

# %% [markdown]
# ### We can see that the air quality in Beijing is Unhealthy but the weather is warm. So not recommended to go out even though the weather is good.

# %%
pd.pivot_table(air_quality,
               index=['TEMP_category','day_of_the_week_type'],
               aggfunc='min',
               values=['PM10','PM2.5'],
               columns='PM2.5_category',
              fill_value=-999)
# Out:
#                                     PM10           \
# PM2.5_category                      Good Moderate
# TEMP_category  day_of_the_week_type
# Very Cold      Weekday                 3        6
#                Weekend                 5        5
# Cold           Weekday                 2        5
#                Weekend                 3        5
# Moderate       Weekday                 2        2
#                Weekend                 2        5
# Warm           Weekday                 2        2
#                Weekend                 3        5
# Hot            Weekday                 2        2
#                Weekend                 3        3
# Extreamely Hot Weekday                50       34
#
#                                                                               \
# PM2.5_category                      Unhealthy for sensitive groups Unhealthy
# TEMP_category  day_of_the_week_type
# Very Cold      Weekday                                           5         9
# ...

# %%
air_quality['TEMP'].describe()
# Out:
# count    95685.000000
# mean        13.729446
# std         11.320713
# min        -16.800000
# 25%          3.500000
# 50%         14.600000
# 75%         23.400000
# max         41.600000
# Name: TEMP, dtype: float64

# %%
#using function to map

# %%
air_quality['wd']
# Out:
# 0        NNW
# 1         NW
# 2         NW
# 3         NW
# 4        NNW
#         ...
# 95680    NNW
# 95681     NW
# 95682     NW
# 95683    NNW
# 95684    NNE
# Name: wd, Length: 95685, dtype: object

# %%
def wd_direction(wd):
    if wd[0]=='N':
        return 'NORTH'
    elif wd[0]=='S':
        return 'SOUTH'
    elif wd[0]=='E':
        return 'EAST'
    else:
        return 'WEST'

# %%
air_quality['wd'].map(wd_direction).value_counts()
# Out:
# NORTH    34068
# SOUTH    26054
# EAST     22699
# WEST     12864
# Name: wd, dtype: int64

# %%
air_quality[['PM2.5','PM10']]
# Out:
#        PM2.5  PM10
# 0        9.0   9.0
# 1        4.0   4.0
# 2        4.0   4.0
# 3        5.0   5.0
# 4        3.0   6.0
# ...      ...   ...
# 95680    9.0   9.0
# 95681   10.0  29.0
# 95682   18.0  32.0
# 95683   15.0  42.0
# 95684   15.0  50.0
#
# [95685 rows x 2 columns]

# %%
air_quality.apply(lambda row: row['PM2.5']/row['PM10'],axis=1)
# Out:
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        0.500000
#            ...
# 95680    1.000000
# 95681    0.344828
# 95682    0.562500
# 95683    0.357143
# 95684    0.300000
# Length: 95685, dtype: float64

# %%
air_quality.head(3)
# Out:
#             date_time  PM2.5  PM10  SO2   NO2     CO    O3  TEMP    PRES  \
# 0 2013-03-01 00:00:00    9.0   9.0  3.0  17.0  300.0  89.0  -0.5  1024.5
# 1 2013-03-01 01:00:00    4.0   4.0  3.0  16.0  300.0  88.0  -0.7  1025.1
# 2 2013-03-01 05:00:00    4.0   4.0  9.0  25.0  300.0  78.0  -2.4  1027.5
#
#    DEWP  ...   wd WSPM  station  year  month day  day_of_the_week  \
# 0 -21.4  ...  NNW  5.7   Dongsi  2013  March   1           Friday
# 1 -22.1  ...   NW  3.9   Dongsi  2013  March   1           Friday
# 2 -21.3  ...   NW  2.4   Dongsi  2013  March   1           Friday
#
#   PM2.5_category day_of_the_week_type TEMP_category
# 0           Good              Weekday     Very Cold
# 1           Good              Weekday     Very Cold
# 2           Good              Weekday     Very Cold
#
# [3 rows x 21 columns]

# %%
air_quality.columns
# Out:
# Index(['date_time', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES',
#        'DEWP', 'RAIN', 'wd', 'WSPM', 'station', 'year', 'month', 'day',
#        'day_of_the_week', 'PM2.5_category', 'day_of_the_week_type',
#        'TEMP_category'],
#       dtype='object')

# %%
air_quality['TEMP_CAT']=pd.qcut(air_quality['TEMP'],q=5,
                               labels=['very cold','cold','moderate','warm','hot'])

# %%
air_quality[['TEMP','TEMP_CAT','RAIN']]
# Out:
#        TEMP   TEMP_CAT  RAIN
# 0      -0.5  very cold   0.0
# 1      -0.7  very cold   0.0
# 2      -2.4  very cold   0.0
# 3      -2.5  very cold   0.0
# 4      -1.4  very cold   0.0
# ...     ...        ...   ...
# 95680  15.4   moderate   0.0
# 95681  14.9   moderate   0.0
# 95682  10.8   moderate   0.0
# 95683  10.5   moderate   0.0
# 95684   8.6       cold   0.0
#
# [95685 rows x 3 columns]

# %%
#making a decission whether to stay home or go outside

# %%
def activity_decission(pm25_cat,temp_cat,rain):
    if pm25_cat in ['Good','Moderate'] and temp_cat in['moderate','warm'] and rain==0:
        return 'Good Day to go out.'
    else:
        return 'Safe to stay indoors.'

# %%
air_quality['Activity_Decission']=air_quality.apply(lambda row: activity_decission(row['PM2.5_category'],row['TEMP_CAT'], row['RAIN']), axis=1)

# %%
air_quality[['PM2.5_category','TEMP','TEMP_CAT','RAIN','Activity_Decission']]
# Out:
#       PM2.5_category  TEMP   TEMP_CAT  RAIN     Activity_Decission
# 0               Good  -0.5  very cold   0.0  Safe to stay indoors.
# 1               Good  -0.7  very cold   0.0  Safe to stay indoors.
# 2               Good  -2.4  very cold   0.0  Safe to stay indoors.
# 3               Good  -2.5  very cold   0.0  Safe to stay indoors.
# 4               Good  -1.4  very cold   0.0  Safe to stay indoors.
# ...              ...   ...        ...   ...                    ...
# 95680           Good  15.4   moderate   0.0    Good Day to go out.
# 95681           Good  14.9   moderate   0.0    Good Day to go out.
# 95682       Moderate  10.8   moderate   0.0    Good Day to go out.
# 95683       Moderate  10.5   moderate   0.0    Good Day to go out.
# 95684       Moderate   8.6       cold   0.0  Safe to stay indoors.
#
# [95685 rows x 5 columns]

# %%
air_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95685 entries, 0 to 95684
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_time             95685 non-null  datetime64[ns]
#  1   PM2.5                 95685 non-null  float64
#  2   PM10                  95685 non-null  float64
#  3   SO2                   95685 non-null  float64
#  4   NO2                   95685 non-null  float64
#  5   CO                    95685 non-null  float64
#  6   O3                    95685 non-null  float64
#  7   TEMP                  95685 non-null  float64
#  8   PRES                  95685 non-null  float64
#  9   DEWP                  95685 non-null  float64
#  10  RAIN                  95685 non-null  float64
#  11  wd                    95685 non-null  object
#  12  WSPM                  95685 non-null  float64
#  13  station               95685 non-null  object
# ...

# %%
air_quality['TEMP'].describe()
# Out:
# count    95685.000000
# mean        13.729446
# std         11.320713
# min        -16.800000
# 25%          3.500000
# 50%         14.600000
# 75%         23.400000
# max         41.600000
# Name: TEMP, dtype: float64

# %%
air_quality['PM2.5_category'].describe()
# Out:
# count         95685
# unique            6
# top       Unhealthy
# freq          34257
# Name: PM2.5_category, dtype: object

# %%
air_quality.describe(include=['object','category','bool'])
# Out:
#            wd  station    month day_of_the_week PM2.5_category  \
# count   95685    95685    95685           95685          95685
# unique     16        3       12               7              6
# top        NE  Tiantan  October          Sunday      Unhealthy
# freq     9447    32843     8495           13931          34257
#
#        day_of_the_week_type TEMP_category TEMP_CAT     Activity_Decission
# count                 95685         95685    95685                  95685
# unique                    2             6        5                      2
# top                 Weekday          Warm     warm  Safe to stay indoors.
# freq                  67942         28526    19189                  83703

# %%
air_quality['TEMP_category'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.displot(data=air_quality,x='TEMP',binwidth=5,height=3,aspect=2)

# %%
sns.displot(data=air_quality,x='TEMP',kind='hist',kde=True)

# %%
sns.catplot(data=air_quality,x='wd',kind='count',aspect=2)

# %%
sns.relplot(data=air_quality,x='TEMP',y='PRES')

# %%
sns.heatmap(data=air_quality.corr(),cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
air_quality['quarter']=air_quality['date_time'].dt.quarter
air_quality.head()
# Out:
#             date_time  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  \
# 0 2013-03-01 00:00:00    9.0   9.0   3.0  17.0  300.0  89.0  -0.5  1024.5
# 1 2013-03-01 01:00:00    4.0   4.0   3.0  16.0  300.0  88.0  -0.7  1025.1
# 2 2013-03-01 05:00:00    4.0   4.0   9.0  25.0  300.0  78.0  -2.4  1027.5
# 3 2013-03-01 06:00:00    5.0   5.0  10.0  29.0  400.0  67.0  -2.5  1028.2
# 4 2013-03-01 07:00:00    3.0   6.0  12.0  40.0  400.0  52.0  -1.4  1029.5
#
#    DEWP  ...  year  month  day day_of_the_week  PM2.5_category  \
# 0 -21.4  ...  2013  March    1          Friday            Good
# 1 -22.1  ...  2013  March    1          Friday            Good
# 2 -21.3  ...  2013  March    1          Friday            Good
# 3 -20.4  ...  2013  March    1          Friday            Good
# 4 -20.4  ...  2013  March    1          Friday            Good
#
#   day_of_the_week_type  TEMP_category   TEMP_CAT     Activity_Decission  \
# ...

# %%
sns.relplot(data=air_quality,x='quarter',y='TEMP',kind='line')

# %%
air_quality.groupby('quarter')['TEMP'].mean()
# Out:
# quarter
# 1     2.899613
# 2    20.437886
# 3    25.092483
# 4     6.427893
# Name: TEMP, dtype: float64

# %%
sns.catplot(data=air_quality,x='quarter',y='TEMP',kind='box',aspect=1.5)

# %%
sns.catplot(data=air_quality,x='quarter',y='TEMP',kind='violin',aspect=1.5)

# %%
sns.catplot(data=air_quality,x='PM2.5_category',kind='count',hue='quarter',aspect=2)

# %%
sns.catplot(data=air_quality,x='PM2.5_category',kind='count',col='quarter',col_wrap=2,aspect=2)

# %%
air_quality.columns
# Out:
# Index(['date_time', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES',
#        'DEWP', 'RAIN', 'wd', 'WSPM', 'station', 'year', 'month', 'day',
#        'day_of_the_week', 'PM2.5_category', 'day_of_the_week_type',
#        'TEMP_category', 'TEMP_CAT', 'Activity_Decission', 'quarter'],
#       dtype='object')

# %%
sns.displot(data=air_quality,x='TEMP', hue='quarter',col='station')

# %%
def is_prior_to_2016(year):
    if year <2016:
        return True
    else:
        return False

air_quality['prior_2016_ind']=air_quality.apply(lambda year: is_prior_to_2016(year['year']),axis=1)

# %%
air_quality['prior_2016_ind']
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 95680    False
# 95681    False
# 95682    False
# 95683    False
# 95684    False
# Name: prior_2016_ind, Length: 95685, dtype: bool

# %%
sns.catplot(data=air_quality, x='quarter',y='TEMP',kind='box',hue='prior_2016_ind')

# %%
sns.catplot(data=air_quality, x='quarter',y='TEMP',kind='bar',hue='prior_2016_ind')

# %%
sns.catplot(data=air_quality,x='PM2.5_category',y='TEMP',hue='quarter',aspect=2)

# %%
sns.pairplot(data=air_quality[['TEMP','PRES','PM2.5','quarter']],hue='quarter')

# %%
sns.relplot(data=air_quality,x='TEMP',y='PRES',hue='quarter',col='year',col_wrap=3,style='quarter')

# %%
sns.relplot(data=air_quality,x='TEMP',y='PRES',hue='quarter',col='year',col_wrap=3,size='PM2.5')
